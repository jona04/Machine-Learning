# %% [markdown]
# # <font color='blue'>Data Science Academy - Machine Learning</font>
#
# # <font color='blue'>Capítulo 10 - Redes Neurais</font>

# %% [markdown]
# ****** Este Jupyter Notebook foi atualizado para a versão 3.6.1. da Linguagem Python em 05/07/2017 ******

# %% [markdown]
# ## Neurolab

# %% [markdown]
# https://pythonhosted.org/neurolab/

# %% [markdown]
# https://code.google.com/archive/p/neurolab/

# %% [markdown]
# https://pypi.python.org/pypi/neurolab

# %%
# !pip install neurolab
# Out:
# Requirement already satisfied: neurolab in /Users/jonatasilva/Documents/ProjetosPython/python/venv37/lib/python3.7/site-packages (0.3.5)
# WARNING: You are using pip version 19.1.1, however version 20.1.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import neurolab as nl
import numpy as np
from sklearn import preprocessing
import matplotlib.pyplot as plt
plt.style.use('ggplot')
# %matplotlib inline

# %%
# Criando datasets de treino
x = np.linspace(-10,10, 60)
y = np.cos(x) * 0.9
size = len(x)
x_train = x.reshape(size,1)
y_train = y.reshape(size,1)

# %%
y_train
# Out:
# array([[-0.75516438],
#        [-0.87500259],
#        [-0.89525382],
#        [-0.8136132 ],
#        [-0.63937252],
#        [-0.39236271],
#        [-0.10069677],
#        [ 0.2024298 ],
#        [ 0.48251716],
#        [ 0.70768762],
#        [ 0.85231376],
#        [ 0.89993521],
#        [ 0.84513201],
#        [ 0.69414148],
#        [ 0.46414838],
#        [ 0.18132899],
#        [-0.12212807],
#        [-0.41168531],
#        [-0.65438727],
#        [-0.82261121],
#        [-0.897211  ],
#        [-0.86969619],
#        [-0.74319832],
#        [-0.53211456],
#        [-0.26046904],
#        [ 0.04082133],
#        [ 0.33746569],
#        [ 0.59570194],
#        [ 0.78613935],
#        [ 0.8871036 ],
#        [ 0.8871036 ],
#        [ 0.78613935],
#        [ 0.59570194],
#        [ 0.33746569],
#        [ 0.04082133],
#        [-0.26046904],
#        [-0.53211456],
#        [-0.74319832],
#        [-0.86969619],
#        [-0.897211  ],
#        [-0.82261121],
#        [-0.65438727],
#        [-0.41168531],
#        [-0.12212807],
#        [ 0.18132899],
#        [ 0.46414838],
#        [ 0.69414148],
#        [ 0.84513201],
#        [ 0.89993521],
#        [ 0.85231376],
#        [ 0.70768762],
#        [ 0.48251716],
#        [ 0.2024298 ],
#        [-0.10069677],
#        [-0.39236271],
#        [-0.63937252],
#        [-0.8136132 ],
#        [-0.89525382],
#        [-0.87500259],
#        [-0.75516438]])

# %%
# ?nl.net.newff

# %%
# ?nl.train.train_gd

# %%
# Criando 4 redes com 0, 1, 2, e 3 camadas e randomizando a inicialização
d = [[1,1],[45,1],[45,45,1],[45,45,45,1]]

for i in range(4):
    net = nl.net.newff([[-10, 10]],d[i])
    train_net = nl.train.train_gd(net, x_train, y_train, epochs = 1000, show = 100)
    outp = net.sim(x_train)
    
    # Plot 
    plt.subplot(2, 1, 1)
    plt.plot(train_net)
    plt.xlabel('Epochs')
    plt.ylabel('Squared error')
    x2 = np.linspace(-10.0,10.0,150)
    y2 = net.sim(x2.reshape(x2.size,1)).reshape(x2.size)
    y3 = outp.reshape(size)
    plt.subplot(2, 1, 2)

    plt.suptitle([i ,'Camadas Ocultas'])
    plt.plot(x2, y2, '-',x , y, '.', x, y3, 'p')
    plt.legend(['Y previsto', 'Y observado'])
    plt.show()
# Out:
# Epoch: 100; Error: 12.647981800494856;
# Epoch: 200; Error: 12.647981800494856;
# Epoch: 300; Error: 12.647981800494856;
# Epoch: 400; Error: 12.647981800494856;
# Epoch: 500; Error: 12.647981800494856;
# Epoch: 600; Error: 12.647981800494856;
# Epoch: 700; Error: 12.647981800494856;
# Epoch: 800; Error: 12.647981800494856;
# Epoch: 900; Error: 12.647981800494856;
# Epoch: 1000; Error: 12.647981800494856;
# The maximum number of train epochs is reached
# Epoch: 100; Error: 2.286746436667863;
# Epoch: 200; Error: 2.2967132167036897;
# Epoch: 300; Error: 3.9807239335239943;
# Epoch: 400; Error: 1.9049912122148862;
# Epoch: 500; Error: 2.310214680897621;
# Epoch: 600; Error: 1.7200779061455522;
# Epoch: 700; Error: 4.825288296103721;
# Epoch: 800; Error: 3.6032684262856725;
# Epoch: 900; Error: 1.8546913747124298;
# Epoch: 1000; Error: 1.501225256749691;
# The maximum number of train epochs is reached
# Epoch: 100; Error: 2.266501475758207;
# Epoch: 200; Error: 0.8828636223683591;
# Epoch: 300; Error: 1.2374505637030748;
# Epoch: 400; Error: 1.1049221933393556;
# Epoch: 500; Error: 0.842294989180031;
# Epoch: 600; Error: 0.5732087377306787;
# Epoch: 700; Error: 0.2952182001360248;
# Epoch: 800; Error: 0.35938376453235743;
# Epoch: 900; Error: 0.11870179904825949;
# Epoch: 1000; Error: 0.09688889791788814;
# The maximum number of train epochs is reached
# Epoch: 100; Error: 2.347413917283272;
# Epoch: 200; Error: 0.7187385885347226;
# Epoch: 300; Error: 0.6215043645403725;
# Epoch: 400; Error: 0.2972728177303211;
# Epoch: 500; Error: 0.12489311541562582;
# Epoch: 600; Error: 0.09408209427613681;
# Epoch: 700; Error: 0.05291557780739675;
# Epoch: 800; Error: 0.023595852798617856;
# Epoch: 900; Error: 0.021889530069609087;
# Epoch: 1000; Error: 0.025959553345840318;
# The maximum number of train epochs is reached

# %% [markdown]
# ### Fim

# %% [markdown]
# ### Obrigado - Data Science Academy - <a href=http://facebook.com/dsacademy>facebook.com/dsacademybr</a>
