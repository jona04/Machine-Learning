# %% [markdown]
# # <font color='blue'>Data Science Academy - Machine Learning</font>
#
# # <font color='blue'>Capítulo 10 - Redes Neurais</font>

# %% [markdown]
# ****** Este Jupyter Notebook foi atualizado para a versão 3.6.1. da Linguagem Python em 05/07/2017 ******

# %% [markdown]
# ## Neurolab

# %% [markdown]
# https://pythonhosted.org/neurolab/

# %% [markdown]
# https://code.google.com/archive/p/neurolab/

# %% [markdown]
# https://pypi.python.org/pypi/neurolab

# %%
# !pip install neurolab
# Out:
# Collecting neurolab
#   Downloading neurolab-0.3.5.tar.gz (645kB)
#     100% |████████████████████████████████| 655kB 985kB/s eta 0:00:01
# Building wheels for collected packages: neurolab
#   Running setup.py bdist_wheel for neurolab ... done
#   Stored in directory: /Users/dmpm/Library/Caches/pip/wheels/45/1e/ca/47c4b838ca247b5f84c66d1fdbba9a576d593ce30d28a48063
# Successfully built neurolab
# Installing collected packages: neurolab
# Successfully installed neurolab-0.3.5

# %%
import neurolab as nl
import numpy as np
from sklearn import preprocessing
import matplotlib.pyplot as plt
plt.style.use('ggplot')
# %matplotlib inline

# %%
# Criando datasets de treino
x = np.linspace(-10,10, 60)
y = np.cos(x) * 0.9
size = len(x)
x_train = x.reshape(size,1)
y_train = y.reshape(size,1)

# %%
# ?nl.net.newff

# %%
# ?nl.train.train_gd

# %%
# Criando 4 redes com 0, 1, 2, e 3 camadas e randomizando a inicialização
d = [[1,1],[45,1],[45,45,1],[45,45,45,1]]

for i in range(4):
    net = nl.net.newff([[-10, 10]],d[i])
    train_net = nl.train.train_gd(net, x_train, y_train, epochs = 1000, show = 100)
    outp = net.sim(x_train)
    
    # Plot 
    plt.subplot(2, 1, 1)
    plt.plot(train_net)
    plt.xlabel('Epochs')
    plt.ylabel('Squared error')
    x2 = np.linspace(-10.0,10.0,150)
    y2 = net.sim(x2.reshape(x2.size,1)).reshape(x2.size)
    y3 = outp.reshape(size)
    plt.subplot(2, 1, 2)

    plt.suptitle([i ,'Camadas Ocultas'])
    plt.plot(x2, y2, '-',x , y, '.', x, y3, 'p')
    plt.legend(['Y previsto', 'Y observado'])
    plt.show()
# Out:
# Epoch: 100; Error: 12.647981800494856;
# Epoch: 200; Error: 12.647981800494856;
# Epoch: 300; Error: 12.647981800494856;
# Epoch: 400; Error: 12.647981800494856;
# Epoch: 500; Error: 12.647981800494856;
# Epoch: 600; Error: 12.647981800494856;
# Epoch: 700; Error: 12.647981800494856;
# Epoch: 800; Error: 12.647981800494856;
# Epoch: 900; Error: 12.647981800494856;
# Epoch: 1000; Error: 12.647981800494856;
# The maximum number of train epochs is reached
# Epoch: 100; Error: 4.494365288558711;
# Epoch: 200; Error: 2.7036097886108172;
# Epoch: 300; Error: 1.4318431424976992;
# Epoch: 400; Error: 5.520897386622247;
# Epoch: 500; Error: 2.009451637919837;
# Epoch: 600; Error: 1.012682171834319;
# Epoch: 700; Error: 4.426632193927932;
# Epoch: 800; Error: 2.5533101730242347;
# Epoch: 900; Error: 1.2673321390682721;
# Epoch: 1000; Error: 1.761219843452801;
# The maximum number of train epochs is reached
# Epoch: 100; Error: 2.890001543959497;
# Epoch: 200; Error: 3.350587360303783;
# Epoch: 300; Error: 0.7311459474214427;
# Epoch: 400; Error: 1.2013873853983634;
# Epoch: 500; Error: 0.33838813548781593;
# Epoch: 600; Error: 0.46314414237093937;
# Epoch: 700; Error: 0.35600002122088154;
# Epoch: 800; Error: 0.30075916600417857;
# Epoch: 900; Error: 0.22753681042813562;
# Epoch: 1000; Error: 0.20724369243404667;
# The maximum number of train epochs is reached
# Epoch: 100; Error: 0.6604339063738441;
# Epoch: 200; Error: 0.6273680800481135;
# Epoch: 300; Error: 0.5645490293773178;
# Epoch: 400; Error: 0.4708090426457152;
# Epoch: 500; Error: 0.13415725306019977;
# Epoch: 600; Error: 0.10399950382875656;
# Epoch: 700; Error: 0.11464552777028833;
# Epoch: 800; Error: 0.07696540322964086;
# Epoch: 900; Error: 0.053563012738802464;
# Epoch: 1000; Error: 0.04831214727877468;
# The maximum number of train epochs is reached

# %% [markdown]
# ### Fim

# %% [markdown]
# ### Obrigado - Data Science Academy - <a href=http://facebook.com/dsacademy>facebook.com/dsacademybr</a>
