# %% [markdown]
# # Notebook Import and Packages

# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %% [markdown]
# # Example 1 - A simple cost function
#
# ## $f(x) = x^2 + x + 1$

# %%
def f(x):
    return x**2+x+1

# %%
# Make Data
x_1 = np.linspace(start=-3, stop=3, num=100)

# %%
# Plot
plt.xlim([-3,3])
plt.ylim([0,12])
plt.title('Cost Function')
plt.xlabel('X', fontsize=16)
plt.ylabel('f(x)', fontsize=16)
plt.plot(x_1, f(x_1))
plt.show()

# %% [markdown]
# ## Slope & Derivative

# %%
def df(x):
    return 2*x + 1

# %%
# Plot function and derivative side by side

plt.figure(figsize=[10,5])

# 1 Chart: Cost Function
plt.subplot(1, 2, 1)

plt.xlim([-3,3])
plt.ylim([0,12])
plt.title('Cost Function')
plt.xlabel('X', fontsize=16)
plt.ylabel('f(x)', fontsize=16)

plt.plot(x_1, f(x_1), color='blue')

# 2 Chart: Derivative
plt.subplot(1, 2, 2)

plt.xlim([-2,3])
plt.ylim([-3,6])
plt.title('Derivatire Cost Function')
plt.xlabel('X', fontsize=16)
plt.ylabel('df(x)', fontsize=16)
plt.grid()
plt.plot(x_1, df(x_1), color='skyblue')

plt.show()

# %% [markdown]
# ## Python Loops & Gradiente Descent

# %%
# Python For Loop
for n in range(5):
    print('Hello', n)
# Out:
# Hello 0
# Hello 1
# Hello 2
# Hello 3
# Hello 4

# %%
# Python While Loop
counter = 0
while counter < 5:
    print('World', counter)
    counter = counter+1
# Out:
# World 0
# World 1
# World 2
# World 3
# World 4

# %%
# Gradiente Descent

new_x = 3
previous_x = 0
step_multiplier = 0.1
precision = 0.00001

for n in range(100):
    previous_x = new_x
    gradient = df(previous_x)
    new_x = previous_x - step_multiplier * gradient
    
    if abs(new_x - previous_x):
        print(n)
        break
    
print('Local minimum accours at:', new_x)
print('Slope or df(x) value at this point is:', df(new_x))
print('f(x) value or cost at this point is:',f(new_x))
# Out:
# 60
# Local minimum accours at: -0.4999957090124856
# Slope or df(x) value at this point is: 8.581975028842947e-06
# f(x) value or cost at this point is: 0.7500000000184126
